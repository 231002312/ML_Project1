# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# !ls /content/drive/MyDrive/ML_Datasets
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Archive.zip

# %%
import os

zip_path = '/content/drive/MyDrive/ML_Datasets/Archive.zip'  # path to your zip
extract_path = '/content/dataset'

if not os.path.exists(extract_path):
    os.makedirs(extract_path)

# Use shell unzip command (robust)
# !unzip -q -o "{zip_path}" -d "{extract_path}"

# Check contents
# !ls "{extract_path}"
# Out:
# __MACOSX  test	train  val

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1./255)
train_generator = train_datagen.flow_from_directory(
    os.path.join(extract_path, 'train'),
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary'
)

test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    os.path.join(extract_path, 'test'),
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary'
)

# Quick check of a batch
images, labels = next(train_generator)
print("Image batch shape:", images.shape)
print("Labels batch shape:", labels.shape)
# Out:
# Found 5216 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.
# Image batch shape: (32, 224, 224, 3)
# Labels batch shape: (32,)

# %%
# !git --version
# !git config --global user.name "231002312"
# !git config --global user.email "231002312@eastdelta.edu.bd"
# Out:
# git version 2.34.1

# %%
# Set your Git display name (can be anything)
# !git config --global user.name "231002312"

# Set your GitHub email (must be your actual GitHub email)
# !git config --global user.email "231002312@eastdelta.edu.bd"

# Verify the settings
# !git config --global user.name
# !git config --global user.email
# Out:
# 231002312
# 231002312@eastdelta.edu.bd

# %%
# Replace with your GitHub repo URL
# !git clone https://github.com/231002312/ML_Project.git
# Out:
# Cloning into 'ML_Project'...
# ...

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

model=models.Sequential()

model.add(layers.Conv2D(32,(3,3),activation='relu',input_shape=(150,150,3)))
model.add(layers.MaxPooling2D(2,2))

model.add(layers.Conv2D(64,(3,3),activation='relu'))
model.add(layers.MaxPooling2D(2,2))

model.add(layers.Conv2D(128,(3,3),activation='relu'))
model.add(layers.MaxPooling2D(2,2))

model.add(layers.Flatten())

model.add(layers.Dense(128,activation='relu'))

model.add(layers.Dense(1,activation='sigmoid'))

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 148, 148, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 74, 74, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
# Change directory to your cloned repository
# %cd /content/ML_Project

# Initialize a new Git repository (this ensures a fresh .git folder)
# !git init

# Set your user name and email for this repository (local configuration)
# !git config user.name "231002312"
# !git config user.email "231002312@eastdelta.edu.bd"

# Check if remote 'origin' already exists and remove it if it does
# !git remote remove origin || true

# Add the remote origin (replace with your repository URL)
# IMPORTANT: Insert your GitHub Personal Access Token (PAT) below
# !git remote add origin https://<YOUR_GITHUB_PERSONAL_ACCESS_TOKEN>@github.com/231002312/ML_Project.git

# Add the notebook file to the staging area
# !git add ML_Project.ipynb

# Commit the changes
# !git commit -m "Add initial ML_Project.ipynb notebook"

# Rename the master branch to main (if it exists)
# !git branch -M main

# Push the changes to GitHub
# You will be prompted to enter your GitHub username and Personal Access Token (PAT).
# If you have 2FA enabled, you must use a PAT instead of your password.
# Generate a PAT from your GitHub settings: Settings > Developer settings > Personal access tokens
# Note: With the PAT in the URL above, you might not be prompted again here.
# !git push -u origin main
# Out:
# /content/ML_Project
# Reinitialized existing Git repository in /content/ML_Project/.git/
# On branch master
# nothing to commit, working tree clean
# fatal: could not read Username for 'https://github.com': No such device or address
